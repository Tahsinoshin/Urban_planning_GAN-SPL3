# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# Define the Generator and Discriminator networks
def build_generator(latent_dim):
    model = keras.Sequential()
    model.add(keras.layers.Dense(128, input_dim=latent_dim))
    model.add(keras.layers.LeakyReLU(alpha=0.2))
    model.add(keras.layers.Dense(784, activation='tanh'))
    model.add(keras.layers.Reshape((28, 28, 1)))
    return model

def build_discriminator(input_shape=(28, 28, 1)):
    model = keras.Sequential()
    model.add(keras.layers.Flatten(input_shape=input_shape))
    model.add(keras.layers.Dense(128))
    model.add(keras.layers.LeakyReLU(alpha=0.2))
    model.add(keras.layers.Dense(1, activation='sigmoid'))
    return model

# Define GAN
def build_gan(generator, discriminator):
    discriminator.trainable = False
    model = keras.Sequential()
    model.add(generator)
    model.add(discriminator)
    return model

# Define GAN parameters
latent_dim = 100
discriminator = build_discriminator()
generator = build_generator(latent_dim)
gan = build_gan(generator, discriminator)

# Compile the models
discriminator.compile(loss='binary_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5), metrics=['accuracy'])
gan.compile(loss='binary_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5))

# Load and preprocess the dataset (MNIST)
(x_train, _), (_, _) = keras.datasets.mnist.load_data()
x_train = x_train / 127.5 - 1.0  # Normalize images to the range [-1, 1]
x_train = np.expand_dims(x_train, axis=3)

# Training parameters
batch_size = 64
epochs = 10000
sample_interval = 1000

# Training the GAN
for epoch in range(epochs):

    # Train the discriminator
    idx = np.random.randint(0, x_train.shape[0], batch_size)
    real_images = x_train[idx]
    labels_real = np.ones((batch_size, 1))

    noise = np.random.normal(0, 1, (batch_size, latent_dim))
    generated_images = generator.predict(noise)
    labels_fake = np.zeros((batch_size, 1))

    d_loss_real = discriminator.train_on_batch(real_images, labels_real)
    d_loss_fake = discriminator.train_on_batch(generated_images, labels_fake)
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

    # Train the generator
    noise = np.random.normal(0, 1, (batch_size, latent_dim))
    labels_gan = np.ones((batch_size, 1))
    g_loss = gan.train_on_batch(noise, labels_gan)

    # Print progress
    if epoch % sample_interval == 0:
        print(f"Epoch {epoch}/{epochs}, D Loss: {d_loss[0]}, G Loss: {g_loss}")

        # Save generated images
        noise = np.random.normal(0, 1, (16, latent_dim))
        generated_images = generator.predict(noise)
        generated_images = 0.5 * generated_images + 0.5  # Rescale to [0, 1]

        fig, axs = plt.subplots(4, 4)
        count = 0
        for i in range(4):
            for j in range(4):
                axs[i, j].imshow(generated_images[count, :, :, 0], cmap='gray')
                axs[i, j].axis('off')
                count += 1
        plt.show()

# Save the generator model
generator.save('gan_generator.h5')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# %cd '/content/drive/My Drive/Urban_planning_with_LUCGAN'
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/Urban_planning_with_LUCGAN'
# /content

# %%
# !git clone https://github.com/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3
# Out:
# Cloning into 'Urban_planning_with_LUCGAN-SPL3'...
# ...

# %%
# !cp '/content/Vabnilla_GAN.ipynb' '/content/drive/My Drive/Urban_planning_with_LUCGAN/Model/'
# Out:
# cp: cannot stat '/content/Vabnilla_GAN.ipynb': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Urban_planning_with_LUCGAN'
# Out:
# /content/drive/My Drive/Urban_planning_with_LUCGAN

# %%
# !cp '/content/Vanilla_GAN.ipynb' '/content/drive/My Drive/Urban_planning_with_LUCGAN/Model/'
# Out:
# cp: cannot stat '/content/Vanilla_GAN.ipynb': No such file or directory

# %%
# %cd '/content/drive/My Drive/Urban_planning_with_LUCGAN'
# !git init
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/Urban_planning_with_LUCGAN'
# /content
# Reinitialized existing Git repository in /content/.git/

# %%
# !git config --global user.email "bsse1107@iit.du.ac.bd"
# !git config --global user.name "Tahsinoshin"

# %%
# !git add .
# !git commit -m "Vanilla GAN commit"
# Out:
# [main (root-commit) c53a957] Vanilla GAN commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 Model/Vanilla_GAN.ipynb

# %%
# !git remote add origin https://github.com/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3
# Out:
# error: remote origin already exists.

# %%
# !git remote set-url origin https://github.com/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3

# %%
# !git remote -v
# Out:
# origin	https://github.com/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3.git (fetch)
# origin	https://github.com/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3.git (push)

# %%
# !git push -u origin main  # Use 'main' or 'master' based on your repository's default branch name
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote -v
# Out:
# origin	https://github.com/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3 (fetch)
# origin	https://github.com/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3 (push)

# %%
# !git add README.md
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# Initialize a Git repository
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# Add a file to the staging area
# !git add README.md
# Out:
# fatal: pathspec 'README.md' did not match any files

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd '/content/drive/My Drive/Urban_planning_with_LUCGAN'
# Out:
# /content/drive/My Drive/Urban_planning_with_LUCGAN

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Navigate to Your Project Directory
# %cd '/content/drive/MyDrive/Urban_planning_with_LUCGAN'

# Initialize a Git Repository
# !git init
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Urban_planning_with_LUCGAN
# Reinitialized existing Git repository in /content/drive/MyDrive/Urban_planning_with_LUCGAN/.git/

# %%
# !git add .

# %%
# !git commit -m "Initial commit"
# Out:
# [main fe58778] Initial commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git config --global user.email "bsse1107@iit.du.ac.bd"
# !git config --global user.name "Tahsinoshin"

# %%
# !git commit -m "Initial commit"
# Out:
# [main bae000e] Initial commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push -u origin main  # Use 'main' or 'master' based on your repository's default branch name
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git branch -M main

# %%
# !git remote add origin https://github.com/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3.git
# Out:
# error: remote origin already exists.

# %%
# !git remote remove origin

# %%
# !git remote add origin https://github.com/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3

# %%
# !git push -u origin main  # Use 'main' or 'master' based on your repository's default branch name
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global credential.helper 'store --file ~/.git-credentials'

# %%
# !git push -u origin main  # Use 'main' or 'master' based on your repository's default branch name
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Urban_planning_with_LUCGAN'
# Out:
# /content/drive/MyDrive/Urban_planning_with_LUCGAN

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Urban_planning_with_LUCGAN/.git/

# %%
# Create and edit a README.md file
# !echo "# Your Project Title" > README.md
# !echo "Description: Write a brief project description here." >> README.md
# !echo "Author: Tahsinoshin" >> README.md

# %%
# !git add .

# %%
# !git commit -m "Initial commit"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@2ca0bce3964f.(none)')

# %%
# !git config --global user.email "bsse1107@iit.du.ac.bd"
# !git config --global user.name "Tahsinoshin"

# %%
# Add specific files or directories
# !git add .
# Alternatively, to add all files and directories
# !git add *

# %%
# !git commit -m "Initial commit"
# Out:
# [main 55cb2b7] Initial commit
#  2 files changed, 4 insertions(+), 1 deletion(-)
#  create mode 100644 README.md

# %%
# !git remote add origin https://github.com/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3.git
# Out:
# error: remote origin already exists.

# %%
# !git push -u origin main  # Use 'main' or 'master' based on your repository's default branch name
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote remove origin

# %%
# !git remote set-url origin https://github.com/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3.git
# Out:
# error: No such remote 'origin'

# %%
# !git remote add origin https://github.com/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3.git

# %%
# !git push -u origin main  # Use 'main' or 'master' based on your repository's default branch name
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global credential.helper store

# %%
# !git push -u origin main  # Use 'main' or 'master' based on your repository's default branch name
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
