# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahsinoshin/Urban_planning_with_LUCGAN-SPL3/blob/main/building_data_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas matplotlib scikit-learn

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-bef0f420-2eed-4aad-bd80-ee029a0fe6f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bef0f420-2eed-4aad-bd80-ee029a0fe6f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Upload the CSV file to Colab
from google.colab import files

uploaded = files.upload()

# Read the uploaded CSV file into a DataFrame
import io
df = pd.read_csv(io.BytesIO(uploaded['building_inventory_021020.csv']), nrows=100)

# Select relevant columns for clustering
features = ['building_typology', 'sqft']
X = df[features]

# Standardize the features
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# Perform K-Means clustering
n_clusters = 5  # Adjust as needed
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df['cluster'] = kmeans.fit_predict(X_std)

# Plot the clustered buildings on a 256x256 image
fig, ax = plt.subplots(figsize=(8, 8))

# Set the aspect ratio to be equal
ax.set_aspect('equal')

# Scatter plot of buildings colored by cluster
scatter = ax.scatter(df.geometry.x, df.geometry.y, c=df['cluster'], cmap='viridis', s=10)

# Add a colorbar
cbar = plt.colorbar(scatter)
cbar.set_label('Cluster')

# Set plot limits based on your area of interest
ax.set_xlim([your_min_x, your_max_x])  # Replace with your actual values
ax.set_ylim([your_min_y, your_max_y])  # Replace with your actual values

# Display the plot
plt.show()
# Out:
#      <input type="file" id="files-5125f55e-e69a-4794-b304-7bb393368250" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5125f55e-e69a-4794-b304-7bb393368250">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
