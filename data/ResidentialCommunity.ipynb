# %%
import json

# Load JSON data from a file
with open('ReCo_json.json', 'r') as json_file:
    data = json.load(json_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e3c02a5efc69> in <cell line: 4>()
#       2
#       3 # Load JSON data from a file
# ----> 4 with open('ReCo_json.json', 'r') as json_file:
#       5     data = json.load(json_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ReCo_json.json'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json

# Define the path to the JSON file in Google Drive
json_file_path = '/content/drive/My Drive/Urban_planning_with_LUCGAN/data/ReCo_json.json'

# Load JSON data from the file
with open(json_file_path, 'r') as json_file:
    data = json.load(json_file)

# %%
import pandas as pd

# Convert JSON data to a DataFrame
df = pd.DataFrame(data)

# Define the path to save the CSV file in Google Drive
csv_file_path = '/content/drive/My Drive/Urban_planning_with_LUCGAN/data/ReCo_json.csv'

# Save the DataFrame as a CSV file
df.to_csv(csv_file_path, index=False)

# %%
selected_columns = ['Latitude', 'Longitude']
df = df[selected_columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-bc5c5d2459f6> in <cell line: 2>()
#       1 selected_columns = ['Latitude', 'Longitude']
# ----> 2 df = df[selected_columns]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# ...

# %%
import pandas as pd

# Load your data into a DataFrame (you might have already done this)
# df = pd.read_csv('your_data.csv')

# Select only 'Latitude' and 'Longitude' columns
selected_columns = ['Latitude', 'Longitude']
df = df[selected_columns]

# Save the selected columns as a CSV file
df.to_csv('latitude_longitude_data.csv', columns=selected_columns, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-59c3a4cafa55> in <cell line: 8>()
#       6 # Select only 'Latitude' and 'Longitude' columns
#       7 selected_columns = ['Latitude', 'Longitude']
# ----> 8 df = df[selected_columns]
#       9
#      10 # Save the selected columns as a CSV file
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# ...
